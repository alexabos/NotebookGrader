# %% [markdown]
# Introducción a Python
# ============================
#
# Unidad 3 - Ejercicios para entregar
# -----------------------------------------------------

# %% [markdown]
# ### Ejercicio 1
#
# Considera la siguiente lista de elementos **(1.5 puntos)**:

# %%
lista = [True, "Python", "Hello World", 56 , 17, False, "Hola Mundo", 3.3]

# %% [markdown]
# a) Lee el código que aparece a continuación y explica detalladamente en qué consiste y el resultado obtenido. (**0.5 puntos**)
#
# **Nota**: Puedes consultar este [enllace](https://docs.python.org/3/tutorial/inputoutput.html) para saber más sobre los f-Strings, unas expresiones muy utilizadas con la función *print()*.

# %%
for n in lista:
    print(f"Element {n} is a", type(n).__name__)
# Out:
# Element True is a  bool
# Element Python is a  str
# Element Hello World is a  str
# Element 56 is a  int
# Element 17 is a  int
# Element False is a  bool
# Element Hola Mundo is a  str
# Element 3.3 is a  float

# %% [markdown]
# **Respuesta**

# %%
# Respuesta

# %% [markdown]
# b) Crea una lista nueva con los elementos de la lista inicial que no son un string. (**0.5 puntos**)

# %%
# Respuesta

# %% [markdown]
# c) Detecta los elementos que són un número entero, e identifica si son divisibles por 2 o no. También se tiene que mostrar por pantalla un mensaje informando de los resultados.
#
# Por ejemplo, un posible mensaje podría ser:
#
# `56 es divisible por 2`
#
# **Nota**: Un número es divisible por 2 cuando, al dividirlo entre 2, el resto es 0. En Python, esto se puede comprobar usando el operador módulo (%), que devuelve el resto de una división.
#
#
# **(0.5 puntos)**

# %%
lista = [True, "Python", "Hello World", 56 , 17, False, "Hola Mundo", 3.3]

# %%
# Respuesta

# %% [markdown]
# ### Ejercicio 2
#
# Las **list comprehension** permiten crear una nueva lista basada en los valores de una lista existente usando una sintaxis más elegante y corta. Vamos a poner en practica esta herramienta usando la lista del ejercicio anterior:

# %%
lista = [True, "Python", "Hello World", 56 , 17, False, "Hola Mundo", 3.3]

# %% [markdown]
# a) Crea una nueva lista con solo los booleans de la lista y muestra el resultado por pantalla. **(0.5 puntos)**
#
# b) Reconstruye la misma lista pero esta vez, reemplazando los valores que no sean de la clase/tipo int por el valor especial nan (Not a Number). **(0.5 puntos)**
#
# **Nota**: Todos los apartados se tienen que resolver usando **list comprehension**.
#
#  **(1 punto)**

# %%
# Respuesta

# %% [markdown]
# ### Ejercicio 3
#
# a) Utiliza la función `range` para mostrar por pantalla los números impares entre 1 y 15 (ambos incluidos): (**0.5 puntos**)
#
# b) Crea una **función** `elementos_pares()` que, dada una lista, cree una nueva lista con sólo los elementos que estaban en posición par. Utiliza `ennumerate` para identificar los índices pares. (**0.5 puntos**)
#
# **Nota**: Considera que el primer elemento de la lista tiene el índice 1. Por ejemplo, en la lista del ejercicio 1, los elementos pares serían "Python", 56 y False. Puede ser útil la opción `start` de [enumerate](https://docs.python.org/3/library/functions.html#enumerate).
#
# **Nota2**: Los números pares cumplen la siguiente expresión: n % 2 = 0. Es decir, son divisibles entre 2.
#
# c) Define un diccionario con 4 elementos que contenga información sobre frutas y su precio. A continuación crea una lista con el mismo número de elementos que el diccionario creado anteriormente (4). En esta lista especifica si has comprado o no el elemento del diccionario. Vamos a usar estas dos estructuras para construir la siguiente frase:
#
# `La fruta "fruta1" con precio "precio1" se ha comprado? "bool_comprado"`
#
# Recorre todos los elementos del diccionario y la lista, de modo que resulte en 4 frases diferentes. La 1a frase sería:
#
# `La fruta kiwi con precio 3€ se ha comprado? True`
#
# (**0.5 puntos**)
#
# **Nota**: Se recomienda el uso del la función zip() y de dict.items().
#
# (**1.5 puntos**)

# %%
# Respuesta

# %% [markdown]
# ### Ejercicio 4
#
# En este ejercicio vamos a crear 2 funciones con las características siguientes:
#
# a) Crea una función que, dada una frase, te devuelva el acrónimo. Por ejemplo, con la frase: `Comité Olímpico Internacional` debería devolver: `COI`
#
# **Nota**: Para simplificar el ejercicio, no es necesario filtrar las preposiciones o determinantes. Si se usa `Barcelona School of Management` se debería obtener `BSOM`.
#
# (**1 punto**)
#
# b) Crea una función que, dado un diccionario que contiene libros y sus respectivas páginas, nos devuelva una lista con los libros que se pueden leer en un número concreto de días. (**1 punto**)
#
# - Como input de la función se deberán indicar el diccionario, el número de páginas que se leen en un día, y el número de días disponibles para leer.
# - Como output se deberá devolver la lista con los libros que cumplen la condición, y también se deberá mostrar por pantalla un mensaje, por ejemplo:
#
# `En 10 días puedo leer los libros siguientes: ['Harry Potter 1', 'Orgullo y prejuicio', 'El viento conoce mi nombre', 'El principito']`
#
#
# (**2 puntos**)

# %%
# Respuesta

# %% [markdown]
# ### Ejercicio 5
#
# Repasando las facturas de electricidad, hemos visto que este verano hemos gastado mucho. Para intentar mejorar nuestra economía y para ser conscientes de nuestro consumo, vamos a crear una calculadora que nos avise, dado un día de la semana y una hora, en qué tramo de tarifa estamos.
#
# Actualmente, hay definidos tres períodos horarios distintos:
#
# - Horas valle: menor demanda y precio.
# - Horas llanas: demanda y precio moderados.
# - Horas punta: mayor demanda y precio.
# - Durante los días laborables (Lunes a Viernes), el tramo depende de las horas. Podéis encontrar la información en este [link](https://selectra.es/energia/info/que-es/discriminacion-horaria)
# - Los fines de semana son siempre horas valle (precio más bajo).
#
# La elección de uno de estos intervalos horarios puede influir significativamente en el importe total a pagar en la factura de electricidad, por lo tanto, queremos desarrollar un programa que nos permita saber en qué tramo estamos antes de poner una lavadora o el A/C.
#
# **(2 puntos)**

# %% [markdown]
# El código debe incorporar los siguientes puntos:
#
# 1. Se deben usar dos variables iniciales: una para almacenar el día de la semana (por ejemplo, "Lunes") y otra para la hora (un número de 0 a 23, por ejemplo, 10). **(0.5 puntos)**
#
# 2. El código debe comprobar si el día es laborable o fin de semana, y, a continuación, identificar a qué tramo pertenece la hora especificada. **(1 punto)**
#
# 3. El código tiene que  mostrar un mensaje en la pantalla describiendo el tramo al que pertenece el día y la hora especificados (por ejemplo, "Lunes a las 10h: Te encuentras en el tramo punta, vigila tu consumo de electricidad"). **(1 punto)**

# %%
# Respuesta

# %% [markdown]
# ### Ejercicio 6
#
# Ahora que ya tenemos el código principal, vamos a mejorarlo para facilitar el uso a los usuarios:
#
# a) Vamos a crear una función (por ejemplo, `calculadora_tramos_luz`) con los siguientes elementos:
#
# - La función tiene que tener dos parámetros de entrada: el día y la hora que deseamos evaluar. **(0.25 puntos)**
#
# - La función deberá mostrar por pantalla el mensaje correspondiente al tramo horario y devolver el nombre el tramo (e.g. "valle"). **(0.5 puntos)**
#
# - En caso de haber algún problema con los parámetros de entrada, se tiene que gestionar el error con try-except y mostrar por pantalla un mensaje explicando el error (por ejemplo, "[ERROR] El rango de horas es de 0 a 23h"). **(1 punto)**
#
# Los errores a tratar son:
# 1.  Se introduce un día de la semana que no existe (e.g. hay algun typo).
# 2.  El formato de las variables introducidas no es válido (e.g. se usa una variable numérica en vez de un string para especificar el día de la semana).
# 3. El rango de las horas no está entre 0 y 23.

# %% [markdown]
# b) Usa estos ejemplos para comprobar que la calculadora de luz funciona correctamente. Muestra el resultado de cada uno de los casos. **(0.25 puntos)**
#
# | día | hora | Mensaje |
# | --- | --- | --- |
# | Martes | 10 | Martes a las 10h: Estás en el tramo punta, vigila tu consumo de electricidad |
# | Domingo | 13 | Fin de semana: Estás en el tramo valle, ¡aprovecha para hacer lavadoras! |
# | Munes | 5 | [ERROR] El formato del dia de la semana introducido no es válido |
# | Viernes | 25 | [ERROR] El rango de horas es de 0 a 23h |

# %% [markdown]
# **(2 puntos)**

# %%
# Respuesta
